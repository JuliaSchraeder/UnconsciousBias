# %% [markdown]
# # Script to exctract mean reaction time
# ----
# - for all 12 timing conditions and all 7 main effects

# %%
#import modules 
import pandas as pd
import ast, os
import numpy as np
import csv
import fileinput
import glob
from numpy import mean

# %% [markdown]
# ### Functions to get mean accuracy for each condition

# %%
#RT of all trials
def total_mean_rt(csvfile, vp_number):
    rt = reaction_time.dropna()
    total_mean_rt = sum(rt)/len(rt)
    
    return total_mean_rt

# %%
#how many answere where correct? in total
def number_corr_ans(csvfile, vp_number):                        
    number_corr_ans_nonformatted = sum(corr_answers) 
    number_corr_ans = "{:.0f}".format(number_corr_ans_nonformatted)      # format value to not show .0
    
    return number_corr_ans

# %%
#How often was a key pressed?
def reaction_number(csvfile, vp_number):
    pure_reaction_time = reaction_time.dropna()                          # delete trials without answer
    reaction_number = len(pure_reaction_time)                            # number of reactions without missing values
    
    return reaction_number

# %%
# mean rt

def rt_happy_happy_unconscious(csvfile, vp_number):
    a = happy_happy_unconscious['key_resp.rt']                          # get RT of happy_happy unconscious trials
    b = a.dropna()                                                      # delete trials without answer
    rt_happy_happy_unconscious = sum(b)/len(b) #get mean
    
    return rt_happy_happy_unconscious

def rt_happy_happy_conscious(csvfile, vp_number):
    a = happy_happy_conscious['key_resp.rt']
    b = a.dropna()
    rt_happy_happy_conscious = sum(b)/len(b)
    
    return rt_happy_happy_conscious

def rt_happy_sad_unconscious(csvfile, vp_number):
    a = happy_sad_unconscious['key_resp.rt']
    b = a.dropna()
    rt_happy_sad_unconscious = sum(b)/len(b)
    
    return rt_happy_sad_unconscious

def rt_happy_sad_conscious(csvfile, vp_number):
    a = happy_sad_conscious['key_resp.rt']
    b = a.dropna()
    rt_happy_sad_conscious = sum(b)/len(b)
    
    return rt_happy_sad_conscious

def rt_happy_neutral_unconscious(csvfile, vp_number):
    a = happy_neutral_unconscious['key_resp.rt']
    b = a.dropna()
    rt_happy_neutral_unconscious = sum(b)/len(b)
    
    return rt_happy_neutral_unconscious

def rt_happy_neutral_conscious(csvfile, vp_number):
    a = happy_neutral_conscious['key_resp.rt']
    b = a.dropna()
    rt_happy_neutral_conscious = sum(b)/len(b)
    
    return rt_happy_neutral_conscious

def rt_sad_happy_unconscious(csvfile, vp_number):
    a = sad_happy_unconscious['key_resp.rt']
    b = a.dropna()
    rt_sad_happy_unconscious = sum(b)/len(b)
    
    return rt_sad_happy_unconscious

def rt_sad_happy_conscious(csvfile, vp_number):
    a = sad_happy_conscious['key_resp.rt']
    b = a.dropna()
    rt_sad_happy_conscious = sum(b)/len(b)
    
    return rt_sad_happy_conscious

def rt_sad_sad_unconscious(csvfile, vp_number):
    a = sad_sad_unconscious['key_resp.rt']
    b = a.dropna()
    rt_sad_sad_unconscious = sum(b)/len(b)
    
    return rt_sad_sad_unconscious

def rt_sad_sad_conscious(csvfile, vp_number):
    a = sad_sad_conscious['key_resp.rt']
    b = a.dropna()
    rt_sad_sad_conscious = sum(b)/len(b)
    
    return rt_sad_sad_conscious

def rt_sad_neutral_unconscious(csvfile, vp_number):
    a = sad_neutral_unconscious['key_resp.rt']
    b = a.dropna()
    rt_sad_neutral_unconscious = sum(b)/len(b)
    
    return rt_sad_neutral_unconscious

def rt_sad_neutral_conscious(csvfile, vp_number):
    a = sad_neutral_conscious['key_resp.rt']
    b = a.dropna()
    rt_sad_neutral_conscious = sum(b)/len(b)
    
    return rt_sad_neutral_conscious

def rt_neutral_happy_unconscious(csvfile, vp_number):
    a = neutral_happy_unconscious['key_resp.rt']
    b = a.dropna()
    rt_neutral_happy_unconscious = sum(b)/len(b)
    
    return rt_neutral_happy_unconscious

def rt_neutral_happy_conscious(csvfile, vp_number):
    a = neutral_happy_conscious['key_resp.rt']
    b = a.dropna()
    rt_neutral_happy_conscious = sum(b)/len(b)
    
    return rt_neutral_happy_conscious

def rt_neutral_sad_unconscious(csvfile, vp_number):
    a = neutral_sad_unconscious['key_resp.rt']
    b = a.dropna()
    rt_neutral_sad_unconscious = sum(b)/len(b)
    
    return rt_neutral_sad_unconscious

def rt_neutral_sad_conscious(csvfile, vp_number):
    a = neutral_sad_conscious['key_resp.rt']
    b = a.dropna()
    rt_neutral_sad_conscious = sum(b)/len(b)
    
    return rt_neutral_sad_conscious

def rt_neutral_neutral_unconscious(csvfile, vp_number):
    a = neutral_neutral_unconscious['key_resp.rt']
    b = a.dropna()
    rt_neutral_neutral_unconscious = sum(b)/len(b)
    
    return rt_neutral_neutral_unconscious

def rt_neutral_neutral_conscious(csvfile, vp_number):
    a = neutral_neutral_conscious['key_resp.rt']
    b = a.dropna()
    rt_neutral_neutral_conscious = sum(b)/len(b)
    
    return rt_neutral_neutral_conscious




def rt_incongruent_unconscious(csvfile,vp_number):
    a = incongruent_unconscious['key_resp.rt']
    b = a.dropna()
    rt_incongruent_unconscious = sum(b)/len(b)
    
    return rt_incongruent_unconscious

def rt_incongruent_conscious(csvfile,vp_number):
    a = incongruent_conscious['key_resp.rt']
    b = a.dropna()
    rt_incongruent_conscious = sum(b)/len(b)
    
    return rt_incongruent_conscious

def rt_congruent_unconscious(csvfile,vp_number):
    a = congruent_unconscious['key_resp.rt']
    b = a.dropna()
    rt_congruent_unconscious = sum(b)/len(b)
    
    return rt_congruent_unconscious

def rt_congruent_conscious(csvfile,vp_number):
    a = congruent_conscious['key_resp.rt']
    b = a.dropna()
    rt_congruent_conscious = sum(b)/len(b)
    
    return rt_congruent_conscious

def rt_incongruent(csvfile,vp_number):
    a = incongruent['key_resp.rt']
    b = a.dropna()
    rt_incongruent = sum(b)/len(b)
    
    return rt_incongruent

def rt_congruent(csvfile,vp_number):
    a = congruent['key_resp.rt']
    b = a.dropna()
    rt_congruent = sum(b)/len(b)
    
    return rt_congruent

def rt_conscious(csvfile,vp_number):
    a = conscious['key_resp.rt']
    b = a.dropna()
    rt_conscious = sum(b)/len(b)
    
    return rt_conscious

def rt_unconscious(csvfile,vp_number):
    a = unconscious['key_resp.rt']
    b = a.dropna()
    rt_unconscious = sum(b)/len(b)
    
    return rt_unconscious


def rt_neutral(csvfile,vp_number):
    a = neutral['key_resp.rt']
    b = a.dropna()
    rt_neutral = sum(b)/len(b)
    
    return rt_neutral

def rt_sad(csvfile,vp_number):
    a = sad['key_resp.rt']
    b = a.dropna()
    rt_sad = sum(b)/len(b)
    
    return rt_sad

def rt_happy(csvfile,vp_number):
    a = happy['key_resp.rt']
    b = a.dropna()
    rt_happy = sum(b)/len(b)
    
    return rt_happy

# %%
### Read in behavioural data

# %%
#read in csv data generated by PsychoPy
participant = glob.glob('Path/*.csv') 
len(participant)
# Out:
# 118

# %%
#create lists to append values and to store them in the dataframe df with mean reactions
list_happy_happy_unconscious = []
list_happy_happy_conscious = []
list_happy_sad_unconscious = []
list_happy_sad_conscious = []
list_happy_neutral_unconscious= []
list_happy_neutral_conscious = []

list_sad_happy_unconscious= []
list_sad_happy_conscious = []
list_sad_sad_unconscious = []
list_sad_sad_conscious = []
list_sad_neutral_unconscious = []
list_sad_neutral_conscious = []

list_neutral_happy_unconscious= []
list_neutral_happy_conscious= []
list_neutral_sad_unconscious = []
list_neutral_sad_conscious = []
list_neutral_neutral_unconscious = []
list_neutral_neutral_conscious = []

list_incongruent_unconscious = []
list_incongruent_conscious = []
list_congruent_unconscious = []
list_congruent_conscious = []

list_incongruent = []
list_congruent = []
list_conscious = []
list_unconscious = []

list_total_mean_rt= []
list_participant_ID = []
list_number_corr_ans = []
list_reaction_number =[]

list_happy= []
list_sad = []
list_neutral = []

# %%
from IPython.display import display, HTML

display(HTML(data="""
<style>
    div#notebook-container    { width: 95%; }
    div#menubar-container     { width: 65%; }
    div#maintoolbar-container { width: 99%; }
</style>
"""))
# Out:
# <style>
#     div#notebook-container    { width: 95%; }
#     div#menubar-container     { width: 65%; }
#     div#maintoolbar-container { width: 99%; }
# </style>

# %% [markdown]
# ### Execute functions for each participant

# %%
for i in participant:
    #read in csv for every participant
    csvfile = pd.read_csv(i, sep =";", decimal=".") #\t , ; ""
 
    #delete first two rows for example trials 
    csvfile = csvfile.iloc[2:]
    
    #insert index of trials for study part starting with 0
    length = len(csvfile)
    csvfile.insert(loc=0, column='index', value=np.arange(length))
    
    #get correct trials
    def correctness(csvfile):
        if csvfile['corrAnsTar'] == 7 and csvfile['key_resp.keys']== "7":
            return 1
        if csvfile['corrAnsTar'] == 8 and csvfile['key_resp.keys']== "8":
            return 1
        if csvfile['corrAnsTar'] == 9 and csvfile['key_resp.keys']== "9":
            return 1
        else:
            return 0
    csvfile['correct'] = csvfile.apply(correctness, axis=1)    
    

    #get correct answers
    corr_answers = csvfile['correct']
    
    #get reaction times
    reaction_time = csvfile['key_resp.rt']
    
    #Get csv file for every Condition
    happy_happy_unconscious = csvfile[(csvfile['PrimerTime120'] == 2) & (csvfile['primeEmotion'] == 'happy') & (csvfile['targetEmotion'] == 'happy')]
    happy_happy_conscious = csvfile[(csvfile['PrimerTime120'] == 18) & (csvfile['primeEmotion'] == 'happy') & (csvfile['targetEmotion'] == 'happy')]
    happy_sad_unconscious = csvfile[(csvfile['PrimerTime120'] == 2) & (csvfile['primeEmotion'] == 'happy') & (csvfile['targetEmotion'] == 'sad')]
    happy_sad_conscious = csvfile[(csvfile['PrimerTime120'] == 18) & (csvfile['primeEmotion'] == 'happy') & (csvfile['targetEmotion'] == 'sad')]
    happy_neutral_unconscious = csvfile[(csvfile['PrimerTime120'] == 2) & (csvfile['primeEmotion'] == 'happy') & (csvfile['targetEmotion'] == 'neutral')]
    happy_neutral_conscious = csvfile[(csvfile['PrimerTime120'] == 18) & (csvfile['primeEmotion'] == 'happy') & (csvfile['targetEmotion'] == 'neutral')]
    
    sad_happy_unconscious = csvfile[(csvfile['PrimerTime120'] == 2) & (csvfile['primeEmotion'] == 'sad') & (csvfile['targetEmotion'] == 'happy')]
    sad_happy_conscious = csvfile[(csvfile['PrimerTime120'] == 18) & (csvfile['primeEmotion'] == 'sad') & (csvfile['targetEmotion'] == 'happy')]
    sad_sad_unconscious = csvfile[(csvfile['PrimerTime120'] == 2) & (csvfile['primeEmotion'] == 'sad') & (csvfile['targetEmotion'] == 'sad')]
    sad_sad_conscious = csvfile[(csvfile['PrimerTime120'] == 18) & (csvfile['primeEmotion'] == 'sad') & (csvfile['targetEmotion'] == 'sad')]
    sad_neutral_unconscious = csvfile[(csvfile['PrimerTime120'] == 2) & (csvfile['primeEmotion'] == 'sad') & (csvfile['targetEmotion'] == 'neutral')]
    sad_neutral_conscious = csvfile[(csvfile['PrimerTime120'] == 18) & (csvfile['primeEmotion'] == 'sad') & (csvfile['targetEmotion'] == 'neutral')]
    
    neutral_happy_unconscious = csvfile[(csvfile['PrimerTime120'] == 2) & (csvfile['primeEmotion'] == 'neutral') & (csvfile['targetEmotion'] == 'happy')]
    neutral_happy_conscious = csvfile[(csvfile['PrimerTime120'] == 18) & (csvfile['primeEmotion'] == 'neutral') & (csvfile['targetEmotion'] == 'happy')]
    neutral_sad_unconscious = csvfile[(csvfile['PrimerTime120'] == 2) & (csvfile['primeEmotion'] == 'neutral') & (csvfile['targetEmotion'] == 'sad')]
    neutral_sad_conscious = csvfile[(csvfile['PrimerTime120'] == 18) & (csvfile['primeEmotion'] == 'neutral') & (csvfile['targetEmotion'] == 'sad')]
    neutral_neutral_unconscious = csvfile[(csvfile['PrimerTime120'] == 2) & (csvfile['primeEmotion'] == 'neutral') & (csvfile['targetEmotion'] == 'neutral')]
    neutral_neutral_conscious = csvfile[(csvfile['PrimerTime120'] == 18) & (csvfile['primeEmotion'] == 'neutral') & (csvfile['targetEmotion'] == 'neutral')]
    
    
    incongruent_unconscious = csvfile[(csvfile['PrimerTime120'] == 2) & (csvfile['targetEmotion'] != csvfile['primeEmotion'])]
    incongruent_conscious = csvfile[(csvfile['PrimerTime120'] == 18) & (csvfile['targetEmotion'] != csvfile['primeEmotion'])]
    congruent_unconscious = csvfile[(csvfile['PrimerTime120'] == 2) & (csvfile['targetEmotion'] == csvfile['primeEmotion'])]
    congruent_conscious = csvfile[(csvfile['PrimerTime120'] == 18) & (csvfile['targetEmotion'] == csvfile['primeEmotion'])]
    
    incongruent = csvfile[csvfile['targetEmotion'] != csvfile['primeEmotion']]
    congruent = csvfile[csvfile['targetEmotion'] == csvfile['primeEmotion']]
    conscious = csvfile[csvfile['PrimerTime120'] == 18]
    unconscious = csvfile[csvfile['PrimerTime120'] == 2]
    
    happy = csvfile[csvfile['targetEmotion'] == 'happy']
    sad = csvfile[csvfile['targetEmotion'] == 'sad']
    neutral= csvfile[csvfile['targetEmotion'] == 'neutral']
    
    #Excecute functions and get one value for each participant
    val_happy_happy_unconscious = rt_happy_happy_unconscious(csvfile,i)
    val_happy_happy_conscious = rt_happy_happy_conscious(csvfile,i)
    val_happy_sad_unconscious = rt_happy_sad_unconscious(csvfile,i)
    val_happy_sad_conscious = rt_happy_sad_conscious(csvfile,i)
    val_happy_neutral_unconscious = rt_happy_neutral_unconscious(csvfile,i)
    val_happy_neutral_conscious = rt_happy_neutral_conscious(csvfile,i)
    val_sad_happy_unconscious = rt_sad_happy_unconscious(csvfile,i)
    val_sad_happy_conscious = rt_sad_happy_conscious(csvfile,i)
    val_sad_sad_unconscious = rt_sad_sad_unconscious(csvfile,i)
    val_sad_sad_conscious = rt_sad_sad_conscious(csvfile,i)
    val_sad_neutral_unconscious = rt_sad_neutral_unconscious(csvfile,i)
    val_sad_neutral_conscious = rt_sad_neutral_conscious(csvfile,i)
    val_neutral_happy_unconscious = rt_neutral_happy_unconscious(csvfile,i)
    val_neutral_happy_conscious = rt_neutral_happy_conscious(csvfile,i)
    val_neutral_sad_unconscious = rt_neutral_sad_unconscious(csvfile,i)
    val_neutral_sad_conscious = rt_neutral_sad_conscious(csvfile,i)
    val_neutral_neutral_unconscious = rt_neutral_neutral_unconscious(csvfile,i)
    val_neutral_neutral_conscious = rt_neutral_neutral_conscious(csvfile,i)
    
    val_incongruent_unconscious = rt_incongruent_unconscious(csvfile,i)
    val_incongruent_conscious = rt_incongruent_conscious(csvfile,i)
    val_congruent_unconscious = rt_congruent_unconscious(csvfile,i)
    val_congruent_conscious =  rt_congruent_conscious(csvfile,i)
     
    val_incongruent = rt_incongruent(csvfile,i)
    val_congruent = rt_congruent(csvfile,i)
    val_conscious = rt_conscious(csvfile,i)
    val_unconscious = rt_unconscious(csvfile,i)
    
    val_participant_ID = i[80:-34] # Macbook i[80:-34] #UKAi[87:-34] 
    val_number_corr_ans = number_corr_ans(csvfile,i)
    val_reaction_number = reaction_number(csvfile,i)
    val_total_mean_rt = total_mean_rt(csvfile,i)
    
    val_happy = rt_happy(csvfile,i)
    val_sad= rt_sad(csvfile,i)
    val_neutral = rt_neutral(csvfile,i)
    
    #append values to append individual value to one list
    list_happy_happy_unconscious.append(val_happy_happy_unconscious)
    list_happy_happy_conscious.append(val_happy_happy_conscious)
    list_happy_sad_unconscious.append(val_happy_sad_unconscious)
    list_happy_sad_conscious.append(val_happy_sad_conscious)
    list_happy_neutral_unconscious.append(val_happy_neutral_unconscious)
    list_happy_neutral_conscious.append(val_happy_neutral_conscious)
    list_sad_happy_unconscious.append(val_sad_happy_unconscious)
    list_sad_happy_conscious.append(val_sad_happy_conscious)
    list_sad_sad_unconscious.append(val_sad_sad_unconscious)
    list_sad_sad_conscious.append(val_sad_sad_conscious)
    list_sad_neutral_unconscious.append(val_sad_neutral_unconscious)
    list_sad_neutral_conscious.append(val_sad_neutral_conscious)
    list_neutral_happy_unconscious.append(val_neutral_happy_unconscious)
    list_neutral_happy_conscious.append(val_neutral_happy_conscious)
    list_neutral_sad_unconscious.append(val_neutral_sad_unconscious)
    list_neutral_sad_conscious.append(val_neutral_sad_conscious)
    list_neutral_neutral_unconscious.append(val_neutral_neutral_unconscious)
    list_neutral_neutral_conscious.append(val_neutral_neutral_conscious)
    
    
    list_incongruent_unconscious.append(val_incongruent_unconscious)
    list_incongruent_conscious.append(val_incongruent_conscious)
    list_congruent_unconscious.append(val_congruent_unconscious)
    list_congruent_conscious.append(val_congruent_conscious)
    
    list_incongruent.append(val_incongruent)
    list_congruent.append(val_congruent)
    list_conscious.append(val_conscious)
    list_unconscious.append(val_unconscious)
    
    list_participant_ID.append(val_participant_ID)
    list_number_corr_ans.append(val_number_corr_ans)
    list_reaction_number.append(val_reaction_number)
    list_total_mean_rt.append(val_total_mean_rt)

    list_happy.append(val_happy)
    list_sad.append(val_sad)
    list_neutral.append(val_neutral)
    
    #Create dataframe 
    rt_data = {'name': list_participant_ID,
                     'number of reactions': list_reaction_number,
                     'number of correct answers': list_number_corr_ans,
                     'total trials': list_total_mean_rt,
                     'incongruent': list_incongruent,
                     'congruent': list_congruent,
                     'conscious': list_conscious,
                     'unconscious': list_unconscious,
                     'happy': list_happy,
                     'sad': list_sad,
                     'neutral': list_neutral,
                     'incongruent_conscious':list_incongruent_conscious,
                     'incongruent_unconscious':list_incongruent_unconscious,
                     'congruent_conscious':list_congruent_conscious,
                     'congruent_unconscious':list_congruent_unconscious, 
                     'happy_happy_unconscious':list_happy_happy_unconscious,
                     'happy_happy_conscious':list_happy_happy_conscious,
                     'happy_sad_unconscious':list_happy_sad_unconscious,
                     'happy_sad_conscious':list_happy_sad_conscious,
                     'happy_neutral_unconscious':list_happy_neutral_unconscious,
                     'happy_neutral_conscious':list_happy_neutral_conscious,
                     'sad_happy_unconscious':list_sad_happy_unconscious,
                     'sad_happy_conscious':list_sad_happy_conscious,
                     'sad_sad_unconscious':list_sad_sad_unconscious,
                     'sad_sad_conscious':list_sad_sad_conscious,
                     'sad_neutral_unconscious':list_sad_neutral_unconscious,
                     'sad_neutral_conscious':list_sad_neutral_conscious,
                     'neutral_happy_unconscious':list_neutral_happy_unconscious,
                     'neutral_happy_conscious':list_neutral_happy_conscious,
                     'neutral_sad_unconscious':list_neutral_sad_unconscious,
                     'neutral_sad_conscious':list_neutral_sad_conscious,
                     'neutral_neutral_unconscious':list_neutral_neutral_unconscious,
                     'neutral_neutral_conscious':list_neutral_neutral_conscious}
    
    mean_rt = pd.DataFrame(data=rt_data)
    mean_rt = mean_rt.round(2)

# %%
i[80:-34]
# Out:
# 'Sub-041'

# %%
mean_rt
# Out:
#         name  number of reactions number of correct answers  total trials  \
# 0    Sub-004                  351                       330          0.42
# 1    Sub-078                  354                       336          0.65
# 2    Sub-056                  354                       335          0.61
# 3    Sub-017                  343                       325          0.69
# 4    Sub-018                  235                       101          0.84
# ..       ...                  ...                       ...           ...
# 113  Sub-044                  349                       344          0.54
# 114  Sub-022                  355                       328          0.53
# 115  Sub-014                  352                       339          0.56
# 116  Sub-048                  350                       345          0.68
# 117  Sub-041                  350                       342          0.63
#
#      incongruent  congruent  conscious  unconscious  happy   sad  ...  \
# ...

# %% [markdown]
# # Do the same for sub-29 until sub-33
#
# (all key presses were stored instead of first, therefore, the datasheet looks a litte bit different)

# %%
#RT of all trials
def total_mean_rt(csvfile, vp_number):
    rt = reaction_time.dropna()
    total_mean_rt = sum(rt)/len(rt)
    
    return total_mean_rt

#how many answere where correct? in total
def number_corr_ans(csvfile, vp_number):                        
    number_corr_ans_nonformatted = sum(corr_answers) 
    number_corr_ans = "{:.0f}".format(number_corr_ans_nonformatted) # format value to not show .0
    
    return number_corr_ans

#How often was a key pressed?
def reaction_number(csvfile, vp_number):
    pure_reaction_time = reaction_time.dropna()                          #delete trials without answer
    reaction_number = len(pure_reaction_time)                          # number of reactions without missing values
    
    return reaction_number    


# mean rt

def rt_happy_happy_unconscious(csvfile, vp_number):
    a = happy_happy_unconscious['RT'] #get RT of happy_happy unconscious trials
    b = a.dropna() # delete trials without answer
    rt_happy_happy_unconscious = sum(b)/len(b) #get mean
    
    return rt_happy_happy_unconscious

def rt_happy_happy_conscious(csvfile, vp_number):
    a = happy_happy_conscious['RT']
    b = a.dropna()
    rt_happy_happy_conscious = sum(b)/len(b)
    
    return rt_happy_happy_conscious

def rt_happy_sad_unconscious(csvfile, vp_number):
    a = happy_sad_unconscious['RT']
    b = a.dropna()
    rt_happy_sad_unconscious = sum(b)/len(b)
    
    return rt_happy_sad_unconscious

def rt_happy_sad_conscious(csvfile, vp_number):
    a = happy_sad_conscious['RT']
    b = a.dropna()
    rt_happy_sad_conscious = sum(b)/len(b)
    
    return rt_happy_sad_conscious

def rt_happy_neutral_unconscious(csvfile, vp_number):
    a = happy_neutral_unconscious['RT']
    b = a.dropna()
    rt_happy_neutral_unconscious = sum(b)/len(b)
    
    return rt_happy_neutral_unconscious

def rt_happy_neutral_conscious(csvfile, vp_number):
    a = happy_neutral_conscious['RT']
    b = a.dropna()
    rt_happy_neutral_conscious = sum(b)/len(b)
    
    return rt_happy_neutral_conscious

def rt_sad_happy_unconscious(csvfile, vp_number):
    a = sad_happy_unconscious['RT']
    b = a.dropna()
    rt_sad_happy_unconscious = sum(b)/len(b)
    
    return rt_sad_happy_unconscious

def rt_sad_happy_conscious(csvfile, vp_number):
    a = sad_happy_conscious['RT']
    b = a.dropna()
    rt_sad_happy_conscious = sum(b)/len(b)
    
    return rt_sad_happy_conscious

def rt_sad_sad_unconscious(csvfile, vp_number):
    a = sad_sad_unconscious['RT']
    b = a.dropna()
    rt_sad_sad_unconscious = sum(b)/len(b)
    
    return rt_sad_sad_unconscious

def rt_sad_sad_conscious(csvfile, vp_number):
    a = sad_sad_conscious['RT']
    b = a.dropna()
    rt_sad_sad_conscious = sum(b)/len(b)
    
    return rt_sad_sad_conscious

def rt_sad_neutral_unconscious(csvfile, vp_number):
    a = sad_neutral_unconscious['RT']
    b = a.dropna()
    rt_sad_neutral_unconscious = sum(b)/len(b)
    
    return rt_sad_neutral_unconscious

def rt_sad_neutral_conscious(csvfile, vp_number):
    a = sad_neutral_conscious['RT']
    b = a.dropna()
    rt_sad_neutral_conscious = sum(b)/len(b)
    
    return rt_sad_neutral_conscious

def rt_neutral_happy_unconscious(csvfile, vp_number):
    a = neutral_happy_unconscious['RT']
    b = a.dropna()
    rt_neutral_happy_unconscious = sum(b)/len(b)
    
    return rt_neutral_happy_unconscious

def rt_neutral_happy_conscious(csvfile, vp_number):
    a = neutral_happy_conscious['RT']
    b = a.dropna()
    rt_neutral_happy_conscious = sum(b)/len(b)
    
    return rt_neutral_happy_conscious

def rt_neutral_sad_unconscious(csvfile, vp_number):
    a = neutral_sad_unconscious['RT']
    b = a.dropna()
    rt_neutral_sad_unconscious = sum(b)/len(b)
    
    return rt_neutral_sad_unconscious

def rt_neutral_sad_conscious(csvfile, vp_number):
    a = neutral_sad_conscious['RT']
    b = a.dropna()
    rt_neutral_sad_conscious = sum(b)/len(b)
    
    return rt_neutral_sad_conscious

def rt_neutral_neutral_unconscious(csvfile, vp_number):
    a = neutral_neutral_unconscious['RT']
    b = a.dropna()
    rt_neutral_neutral_unconscious = sum(b)/len(b)
    
    return rt_neutral_neutral_unconscious

def rt_neutral_neutral_conscious(csvfile, vp_number):
    a = neutral_neutral_conscious['RT']
    b = a.dropna()
    rt_neutral_neutral_conscious = sum(b)/len(b)
    
    return rt_neutral_neutral_conscious


def rt_incongruent_unconscious(csvfile,vp_number):
    a = incongruent_unconscious['RT']
    b = a.dropna()
    rt_incongruent_unconscious = sum(b)/len(b)
    
    return rt_incongruent_unconscious

def rt_incongruent_conscious(csvfile,vp_number):
    a = incongruent_conscious['RT']
    b = a.dropna()
    rt_incongruent_conscious = sum(b)/len(b)
    
    return rt_incongruent_conscious

def rt_congruent_unconscious(csvfile,vp_number):
    a = congruent_unconscious['RT']
    b = a.dropna()
    rt_congruent_unconscious = sum(b)/len(b)
    
    return rt_congruent_unconscious

def rt_congruent_conscious(csvfile,vp_number):
    a = congruent_conscious['RT']
    b = a.dropna()
    rt_congruent_conscious = sum(b)/len(b)
    
    return rt_congruent_conscious

def rt_incongruent(csvfile,vp_number):
    a = incongruent['RT']
    b = a.dropna()
    rt_incongruent = sum(b)/len(b)
    
    return rt_incongruent

def rt_congruent(csvfile,vp_number):
    a = congruent['RT']
    b = a.dropna()
    rt_congruent = sum(b)/len(b)
    
    return rt_congruent

def rt_conscious(csvfile,vp_number):
    a = conscious['RT']
    b = a.dropna()
    rt_conscious = sum(b)/len(b)
    
    return rt_conscious

def rt_unconscious(csvfile,vp_number):
    a = unconscious['RT']
    b = a.dropna()
    rt_unconscious = sum(b)/len(b)
    
    return rt_unconscious


def rt_neutral(csvfile,vp_number):
    a = neutral['RT']
    b = a.dropna()
    rt_neutral = sum(b)/len(b)
    
    return rt_neutral

def rt_sad(csvfile,vp_number):
    a = sad['RT']
    b = a.dropna()
    rt_sad = sum(b)/len(b)
    
    return rt_sad

def rt_happy(csvfile,vp_number):
    a = happy['RT']
    b = a.dropna()
    rt_happy = sum(b)/len(b)
    
    return rt_happy

# %%
participant = (glob.glob('Path/All_Keys/*.csv'))
len(participant)
# Out:
# 5

# %%
#create lists to append values and to store them in the dataframe df with mean reactions
list_happy_happy_unconscious = []
list_happy_happy_conscious = []
list_happy_sad_unconscious = []
list_happy_sad_conscious = []
list_happy_neutral_unconscious= []
list_happy_neutral_conscious = []
list_sad_happy_unconscious= []
list_sad_happy_conscious = []
list_sad_sad_unconscious = []
list_sad_sad_conscious = []
list_sad_neutral_unconscious = []
list_sad_neutral_conscious = []
list_neutral_happy_unconscious= []
list_neutral_happy_conscious= []
list_neutral_sad_unconscious = []
list_neutral_sad_conscious = []
list_neutral_neutral_unconscious = []
list_neutral_neutral_conscious = []

list_incongruent_unconscious = []
list_incongruent_conscious = []
list_congruent_unconscious = []
list_congruent_conscious = []

list_incongruent = []
list_congruent = []
list_conscious = []
list_unconscious = []

list_total_mean_rt= []
list_participant_ID = []
list_number_corr_ans = []
list_reaction_number =[]

list_happy= []
list_sad = []
list_neutral = []

# %%
for i in participant:
    #read in csv for every participant
    csvfile = pd.read_csv(i, sep =";") #\t , ; ""
    #delete first two rows for example trials 
    csvfile = csvfile.iloc[2:]
    #insert index of trials for study part starting with 0
    length = len(csvfile)
    csvfile.insert(loc=0, column='index', value=np.arange(length))
    
    #all keypresses are saved as list like this: ['7'] but we just want the 7!:
    csvfile['key_resp.keys'] = csvfile['key_resp.keys'].str[2] 
    csvfile['key_resp.rt'] = csvfile['key_resp.rt'].str[1:8]
    
    #get correct trials
    def correctness(csvfile):
        if csvfile['corrAnsTar'] == 7 and csvfile['key_resp.keys']== "7":
            return 1
        if csvfile['corrAnsTar'] == 8 and csvfile['key_resp.keys']== "8":
            return 1
        if csvfile['corrAnsTar'] == 9 and csvfile['key_resp.keys']== "9":
            return 1
        else:
            return 0
    csvfile['correct'] = csvfile.apply(correctness, axis=1)    
    

    #get correct answers
    corr_answers = csvfile['correct']
    #get reaction times
    csvfile = csvfile.rename({'key_resp.rt': 'RT'}, axis=1)               # rename column
    csvfile["RT"] = pd.to_numeric(csvfile["RT"],errors = 'coerce')        # transform object into float
    reaction_time = csvfile['RT']

    
        #Get csv file for every Condition
    happy_happy_unconscious = csvfile[(csvfile['PrimerTime120'] == 2) & (csvfile['primeEmotion'] == 'happy') & (csvfile['targetEmotion'] == 'happy')]
    happy_happy_conscious = csvfile[(csvfile['PrimerTime120'] == 18) & (csvfile['primeEmotion'] == 'happy') & (csvfile['targetEmotion'] == 'happy')]
    happy_sad_unconscious = csvfile[(csvfile['PrimerTime120'] == 2) & (csvfile['primeEmotion'] == 'happy') & (csvfile['targetEmotion'] == 'sad')]
    happy_sad_conscious = csvfile[(csvfile['PrimerTime120'] == 18) & (csvfile['primeEmotion'] == 'happy') & (csvfile['targetEmotion'] == 'sad')]
    happy_neutral_unconscious = csvfile[(csvfile['PrimerTime120'] == 2) & (csvfile['primeEmotion'] == 'happy') & (csvfile['targetEmotion'] == 'neutral')]
    happy_neutral_conscious = csvfile[(csvfile['PrimerTime120'] == 18) & (csvfile['primeEmotion'] == 'happy') & (csvfile['targetEmotion'] == 'neutral')]
    
    sad_happy_unconscious = csvfile[(csvfile['PrimerTime120'] == 2) & (csvfile['primeEmotion'] == 'sad') & (csvfile['targetEmotion'] == 'happy')]
    sad_happy_conscious = csvfile[(csvfile['PrimerTime120'] == 18) & (csvfile['primeEmotion'] == 'sad') & (csvfile['targetEmotion'] == 'happy')]
    sad_sad_unconscious = csvfile[(csvfile['PrimerTime120'] == 2) & (csvfile['primeEmotion'] == 'sad') & (csvfile['targetEmotion'] == 'sad')]
    sad_sad_conscious = csvfile[(csvfile['PrimerTime120'] == 18) & (csvfile['primeEmotion'] == 'sad') & (csvfile['targetEmotion'] == 'sad')]
    sad_neutral_unconscious = csvfile[(csvfile['PrimerTime120'] == 2) & (csvfile['primeEmotion'] == 'sad') & (csvfile['targetEmotion'] == 'neutral')]
    sad_neutral_conscious = csvfile[(csvfile['PrimerTime120'] == 18) & (csvfile['primeEmotion'] == 'sad') & (csvfile['targetEmotion'] == 'neutral')]
    
    neutral_happy_unconscious = csvfile[(csvfile['PrimerTime120'] == 2) & (csvfile['primeEmotion'] == 'neutral') & (csvfile['targetEmotion'] == 'happy')]
    neutral_happy_conscious = csvfile[(csvfile['PrimerTime120'] == 18) & (csvfile['primeEmotion'] == 'neutral') & (csvfile['targetEmotion'] == 'happy')]
    neutral_sad_unconscious = csvfile[(csvfile['PrimerTime120'] == 2) & (csvfile['primeEmotion'] == 'neutral') & (csvfile['targetEmotion'] == 'sad')]
    neutral_sad_conscious = csvfile[(csvfile['PrimerTime120'] == 18) & (csvfile['primeEmotion'] == 'neutral') & (csvfile['targetEmotion'] == 'sad')]
    neutral_neutral_unconscious = csvfile[(csvfile['PrimerTime120'] == 2) & (csvfile['primeEmotion'] == 'neutral') & (csvfile['targetEmotion'] == 'neutral')]
    neutral_neutral_conscious = csvfile[(csvfile['PrimerTime120'] == 18) & (csvfile['primeEmotion'] == 'neutral') & (csvfile['targetEmotion'] == 'neutral')]
    
    
    incongruent_unconscious = csvfile[(csvfile['PrimerTime120'] == 2) & (csvfile['targetEmotion'] != csvfile['primeEmotion'])]
    incongruent_conscious = csvfile[(csvfile['PrimerTime120'] == 18) & (csvfile['targetEmotion'] != csvfile['primeEmotion'])]
    congruent_unconscious = csvfile[(csvfile['PrimerTime120'] == 2) & (csvfile['targetEmotion'] == csvfile['primeEmotion'])]
    congruent_conscious = csvfile[(csvfile['PrimerTime120'] == 18) & (csvfile['targetEmotion'] == csvfile['primeEmotion'])]
    
    incongruent = csvfile[csvfile['targetEmotion'] != csvfile['primeEmotion']]
    congruent = csvfile[csvfile['targetEmotion'] == csvfile['primeEmotion']]
    conscious = csvfile[csvfile['PrimerTime120'] == 18]
    unconscious = csvfile[csvfile['PrimerTime120'] == 2]
    
    happy = csvfile[csvfile['targetEmotion'] == 'happy']
    sad = csvfile[csvfile['targetEmotion'] == 'sad']
    neutral= csvfile[csvfile['targetEmotion'] == 'neutral']
    
    #Excecute functions and get one value for each participant
    val_happy_happy_unconscious = rt_happy_happy_unconscious(csvfile,i)
    val_happy_happy_conscious = rt_happy_happy_conscious(csvfile,i)
    val_happy_sad_unconscious = rt_happy_sad_unconscious(csvfile,i)
    val_happy_sad_conscious = rt_happy_sad_conscious(csvfile,i)
    val_happy_neutral_unconscious = rt_happy_neutral_unconscious(csvfile,i)
    val_happy_neutral_conscious = rt_happy_neutral_conscious(csvfile,i)
    val_sad_happy_unconscious = rt_sad_happy_unconscious(csvfile,i)
    val_sad_happy_conscious = rt_sad_happy_conscious(csvfile,i)
    val_sad_sad_unconscious = rt_sad_sad_unconscious(csvfile,i)
    val_sad_sad_conscious = rt_sad_sad_conscious(csvfile,i)
    val_sad_neutral_unconscious = rt_sad_neutral_unconscious(csvfile,i)
    val_sad_neutral_conscious = rt_sad_neutral_conscious(csvfile,i)
    val_neutral_happy_unconscious = rt_neutral_happy_unconscious(csvfile,i)
    val_neutral_happy_conscious = rt_neutral_happy_conscious(csvfile,i)
    val_neutral_sad_unconscious = rt_neutral_sad_unconscious(csvfile,i)
    val_neutral_sad_conscious = rt_neutral_sad_conscious(csvfile,i)
    val_neutral_neutral_unconscious = rt_neutral_neutral_unconscious(csvfile,i)
    val_neutral_neutral_conscious = rt_neutral_neutral_conscious(csvfile,i)
    
    val_incongruent_unconscious = rt_incongruent_unconscious(csvfile,i)
    val_incongruent_conscious = rt_incongruent_conscious(csvfile,i)
    val_congruent_unconscious = rt_congruent_unconscious(csvfile,i)
    val_congruent_conscious =  rt_congruent_conscious(csvfile,i)
     
    val_incongruent = rt_incongruent(csvfile,i)
    val_congruent = rt_congruent(csvfile,i)
    val_conscious = rt_conscious(csvfile,i)
    val_unconscious = rt_unconscious(csvfile,i)
    
    val_participant_ID = i[89:-34] #Macbook i[89:-34] #ukai[96:-34] 
    val_number_corr_ans = number_corr_ans(csvfile,i)
    val_reaction_number = reaction_number(csvfile,i)
    val_total_mean_rt = total_mean_rt(csvfile,i)
    
    val_happy = rt_happy(csvfile,i)
    val_sad= rt_sad(csvfile,i)
    val_neutral = rt_neutral(csvfile,i)
    
    #append values to append individual value to one list
    list_happy_happy_unconscious.append(val_happy_happy_unconscious)
    list_happy_happy_conscious.append(val_happy_happy_conscious)
    list_happy_sad_unconscious.append(val_happy_sad_unconscious)
    list_happy_sad_conscious.append(val_happy_sad_conscious)
    list_happy_neutral_unconscious.append(val_happy_neutral_unconscious)
    list_happy_neutral_conscious.append(val_happy_neutral_conscious)
    list_sad_happy_unconscious.append(val_sad_happy_unconscious)
    list_sad_happy_conscious.append(val_sad_happy_conscious)
    list_sad_sad_unconscious.append(val_sad_sad_unconscious)
    list_sad_sad_conscious.append(val_sad_sad_conscious)
    list_sad_neutral_unconscious.append(val_sad_neutral_unconscious)
    list_sad_neutral_conscious.append(val_sad_neutral_conscious)
    list_neutral_happy_unconscious.append(val_neutral_happy_unconscious)
    list_neutral_happy_conscious.append(val_neutral_happy_conscious)
    list_neutral_sad_unconscious.append(val_neutral_sad_unconscious)
    list_neutral_sad_conscious.append(val_neutral_sad_conscious)
    list_neutral_neutral_unconscious.append(val_neutral_neutral_unconscious)
    list_neutral_neutral_conscious.append(val_neutral_neutral_conscious)
    
    list_incongruent_unconscious.append(val_incongruent_unconscious)
    list_incongruent_conscious.append(val_incongruent_conscious)
    list_congruent_unconscious.append(val_congruent_unconscious)
    list_congruent_conscious.append(val_congruent_conscious)
    
    list_incongruent.append(val_incongruent)
    list_congruent.append(val_congruent)
    list_conscious.append(val_conscious)
    list_unconscious.append(val_unconscious)
    
    list_participant_ID.append(val_participant_ID)
    list_number_corr_ans.append(val_number_corr_ans)
    list_reaction_number.append(val_reaction_number)
    list_total_mean_rt.append(val_total_mean_rt)
    
    list_happy.append(val_happy)
    list_sad.append(val_sad)
    list_neutral.append(val_neutral)
    
    
    #Create dataframe 
    rt_data_2 = {'name': list_participant_ID,
                     'number of reactions': list_reaction_number,
                     'number of correct answers': list_number_corr_ans,
                     'total trials': list_total_mean_rt,
                     'incongruent': list_incongruent,
                     'congruent': list_congruent,
                     'conscious': list_conscious,
                     'unconscious': list_unconscious,
                     'happy': list_happy,
                     'sad': list_sad,
                     'neutral': list_neutral,
                     'incongruent_conscious':list_incongruent_conscious,
                     'incongruent_unconscious':list_incongruent_unconscious,
                     'congruent_conscious':list_congruent_conscious,
                     'congruent_unconscious':list_congruent_unconscious, 
                     'happy_happy_unconscious':list_happy_happy_unconscious,
                     'happy_happy_conscious':list_happy_happy_conscious,
                     'happy_sad_unconscious':list_happy_sad_unconscious,
                     'happy_sad_conscious':list_happy_sad_conscious,
                     'happy_neutral_unconscious':list_happy_neutral_unconscious,
                     'happy_neutral_conscious':list_happy_neutral_conscious,
                     'sad_happy_unconscious':list_sad_happy_unconscious,
                     'sad_happy_conscious':list_sad_happy_conscious,
                     'sad_sad_unconscious':list_sad_sad_unconscious,
                     'sad_sad_conscious':list_sad_sad_conscious,
                     'sad_neutral_unconscious':list_sad_neutral_unconscious,
                     'sad_neutral_conscious':list_sad_neutral_conscious,
                     'neutral_happy_unconscious':list_neutral_happy_unconscious,
                     'neutral_happy_conscious':list_neutral_happy_conscious,
                     'neutral_sad_unconscious':list_neutral_sad_unconscious,
                     'neutral_sad_conscious':list_neutral_sad_conscious,
                     'neutral_neutral_unconscious':list_neutral_neutral_unconscious,
                     'neutral_neutral_conscious':list_neutral_neutral_conscious}
    
    mean_rt_2 = pd.DataFrame(data=rt_data_2)
    mean_rt_2 = mean_rt_2.round(2)

# %%
i[89:-34]
# Out:
# 'Sub-031'

# %% [markdown]
# ### Merge two datasets

# %%
#merge frames
frames = [mean_rt,mean_rt_2]

result = pd.concat(frames)
len(result)
# Out:
# 123

# %%
result.to_excel(r'Path/BackwardMask_Mean_RT.xlsx',sheet_name='Sheet_name_1')

# %%
result
# Out:
#        name  number of reactions number of correct answers  total trials  \
# 0   Sub-004                  351                       330          0.42
# 1   Sub-078                  354                       336          0.65
# 2   Sub-056                  354                       335          0.61
# 3   Sub-017                  343                       325          0.69
# 4   Sub-018                  235                       101          0.84
# ..      ...                  ...                       ...           ...
# 0   Sub-033                  352                       329          0.66
# 1   Sub-029                  358                       334          0.45
# 2   Sub-032                  352                       335          0.61
# 3   Sub-030                  333                       258          0.72
# 4   Sub-031                  354                       345          0.62
#
#     incongruent  congruent  conscious  unconscious  happy   sad  ...  \
# ...
